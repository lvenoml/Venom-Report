# %%
from nltk.stem import RSLPStemmer

# %%
def Tokenize(sentence):
    sentence = sentence.lower()
    sentence = nltk.word_tokenize(sentence)
    return sentence

# %%
def Stemming(sentence):
    stemmer = RSLPStemmer()
    phrase = []
    for word in sentence:
        phrase.append(stemmer.stem(word.lower()))
    return phrase

# %%
def RemoveStopWords(sentence):
    stopwords = nltk.corpus.stopwords.words('portuguese')
    phrase = []
    for word in sentence:
        if word not in stopwords:
            phrase.append(word)
    return phrase

# %%
import nltk
nltk.download('book')
nltk.download('machado') 
nltk.download('mac_morpho')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/caroline/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/caroline/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/caroline/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/caroline/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/caroline/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/caroline/nltk_data...
# ...

# %%
from nltk.corpus import machado   #importando todos os livros de Machado

livro_raw = ""

for id in machado.fileids():
    livro_raw += (machado.raw(id))   #colocando todos os livro na string

print(livro_raw[:30])
print(len(livro_raw))

# imports
import nltk
from nltk import word_tokenize
stopwords = nltk.corpus.stopwords.words('portuguese')

#colocando todas as palavras em minusculo
livro_raw = livro_raw.lower()

#tokenizando as sentenças
sentences = nltk.sent_tokenize(livro_raw)

print(sentences[:30])
# Out:
# Conto, Contos Fluminenses, 187
# 14840456
# ...

# %%
#tokenizando cada palavra de cada sentença

tokens_sentences = []
for i in sentences:
    tokens_sentences.append(word_tokenize(i))
    
print(tokens_sentences[:30])
# Out:
# [['conto', ',', 'contos', 'fluminenses', ',', '1870', 'contos', 'fluminenses', 'texto-fonte', ':', 'obra', 'completa', ',', 'machado', 'de', 'assis', ',', 'vol', '.'], ['ii', ',', 'rio', 'de', 'janeiro', ':', 'nova', 'aguilar', ',', '1994.', 'publicado', 'originalmente', 'pela', 'editora', 'garnier', ',', 'rio', 'de', 'janeiro', ',', 'em', '1870.', 'índice', 'miss', 'dollar', 'luís', 'soares', 'a', 'mulher', 'de', 'preto', 'o', 'segredo', 'de', 'augusta', 'confissões', 'de', 'uma', 'viúva', 'moça', 'linha', 'reta', 'e', 'linha', 'curva', 'frei', 'simão', 'miss', 'dollar', 'índice', 'capítulo', 'primeiro', 'capítulo', 'ii', 'capítulo', 'iii', 'capítulo', 'iv', 'capítulo', 'v', 'capítulo', 'vi', 'capítulo', 'vii', 'capítulo', 'viii', 'capítulo', 'primeiro', 'era', 'conveniente', 'ao', 'romance', 'que', 'o', 'leitor', 'ficasse', 'muito', 'tempo', 'sem', 'saber', 'quem', 'era', 'miss', 'dollar', '.'], ['mas', 'por', 'outro', 'lado', ',', 'sem', 'a', 'apresentação', 'de', 'miss', 'dollar'
# ...

# %%
#imports
stopwords = nltk.corpus.stopwords.words('portuguese')

#retirando as stopwords de cada frase
tl2=[]
for sentence in tokens_sentences:
    tl2_sentence=[]
    for word in sentence:
        if word not in stopwords:
            tl2_sentence.append(word)
    tl2.append(tl2_sentence)

book = []
for t in tl2:
    book.append([word for word in t if word.isalpha()])
print(book[:30])
# Out:
# [['conto', 'contos', 'fluminenses', 'contos', 'fluminenses', 'obra', 'completa', 'machado', 'assis', 'vol'], ['ii', 'rio', 'janeiro', 'nova', 'aguilar', 'publicado', 'originalmente', 'editora', 'garnier', 'rio', 'janeiro', 'índice', 'miss', 'dollar', 'luís', 'soares', 'mulher', 'preto', 'segredo', 'augusta', 'confissões', 'viúva', 'moça', 'linha', 'reta', 'linha', 'curva', 'frei', 'simão', 'miss', 'dollar', 'índice', 'capítulo', 'primeiro', 'capítulo', 'ii', 'capítulo', 'iii', 'capítulo', 'iv', 'capítulo', 'v', 'capítulo', 'vi', 'capítulo', 'vii', 'capítulo', 'viii', 'capítulo', 'primeiro', 'conveniente', 'romance', 'leitor', 'ficasse', 'tempo', 'saber', 'miss', 'dollar'], ['outro', 'lado', 'apresentação', 'miss', 'dollar', 'autor', 'obrigado', 'longas', 'digressões', 'encheriam', 'papel', 'adiantar', 'ação'], ['hesitação', 'possível', 'vou', 'miss', 'dollar'], ['leitor', 'rapaz', 'dado', 'gênio', 'melancólico', 'imagina', 'miss', 'dollar', 'inglesa', 'pálida', 'delgada', 'escassa', 
# ...

# %%
#imports
stemmer = nltk.stem.RSLPStemmer()

# aplicando o stemming em cada palavra de cada frase
livro = []
for sentence in book:
    sentences_strem=[]
    for word in sentence:
        sentences_strem.append(stemmer.stem(word))
    livro.append(sentences_strem)
    
    
print(livro[:30])
# Out:
# [['cont', 'cont', 'flumin', 'cont', 'flumin', 'obr', 'complet', 'mach', 'assil', 'vol'], ['ii', 'rio', 'jan', 'nov', 'aguil', 'public', 'orig', 'edit', 'garni', 'rio', 'jan', 'índic', 'mis', 'doll', 'luí', 'so', 'mulh', 'pret', 'segred', 'august', 'confiss', 'viúv', 'moç', 'linh', 'ret', 'linh', 'curv', 'fre', 'sim', 'mis', 'doll', 'índic', 'capítul', 'prim', 'capítul', 'ii', 'capítul', 'iii', 'capítul', 'iv', 'capítul', 'v', 'capítul', 'vi', 'capítul', 'vii', 'capítul', 'vii', 'capítul', 'prim', 'conveni', 'romanc', 'leit', 'fic', 'temp', 'sab', 'mis', 'doll'], ['outr', 'lad', 'apresent', 'mis', 'doll', 'autor', 'obrig', 'long', 'digress', 'ench', 'papel', 'adiant', 'açã'], ['hesit', 'possível', 'vou', 'mis', 'doll'], ['leit', 'rapaz', 'dad', 'gêni', 'melancól', 'imagin', 'mis', 'doll', 'ingl', 'pál', 'delg', 'escass', 'carn', 'sang', 'abr', 'fl', 'rost', 'doi', 'grand', 'olh', 'azuil', 'sacud', 'vent', 'uma', 'long', 'tranç', 'loir'], ['moç', 'quest', 'dev', 'ser', 'vapor', 'ideal'
# ...

# %%
from gensim.models import Word2Vec

# sem nenhum outro parametro
model = Word2Vec(livro)

vocabulary = list(model.wv.vocab)
print(vocabulary)
# Out:
# ['cont', 'flumin', 'obr', 'complet', 'mach', 'assil', 'vol', 'ii', 'rio', 'jan', 'nov', 'aguil', 'public', 'orig', 'edit', 'garni', 'índic', 'mis', 'doll', 'luí', 'so', 'mulh', 'pret', 'segred', 'august', 'confiss', 'viúv', 'moç', 'linh', 'ret', 'curv', 'fre', 'sim', 'capítul', 'prim', 'iii', 'iv', 'v', 'vi', 'vii', 'conveni', 'romanc', 'leit', 'fic', 'temp', 'sab', 'outr', 'lad', 'apresent', 'autor', 'obrig', 'long', 'digress', 'ench', 'papel', 'adiant', 'açã', 'hesit', 'possível', 'vou', 'rapaz', 'dad', 'gêni', 'melancól', 'imagin', 'ingl', 'pál', 'delg', 'escass', 'carn', 'sang', 'abr', 'fl', 'rost', 'doi', 'grand', 'olh', 'azuil', 'sacud', 'vent', 'uma', 'tranç', 'loir', 'quest', 'dev', 'ser', 'vapor', 'ideal', 'cri', 'shakespe', 'contr', 'britân', 'aliment', 'liberdad', 'rein', 'unid', 'tal', 'ter', 'poet', 'tennyson', 'cor', 'ler', 'lamartin', 'soub', 'portugu', 'sonet', 'cam', 'cant', 'gonçalv', 'dia', 'chá', 'semelh', 'criat', 'algum', 'confeit', 'biscoit', 'acud', 'urg', 'es
# ...

# %%
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8548823595046997), ('pobr', 0.8005064129829407), ('chor', 0.746495246887207), ('debulh', 0.7462098598480225), ('defunt', 0.7264231443405151), ('ai', 0.7259718775749207), ('infeliz', 0.723885178565979), ('mulh', 0.7091758251190186), ('gord', 0.6921967267990112), ('tern', 0.6895545721054077)]

# %%
# adicionando o primeiro parâmetro
# Ignora todas as palavras com frequência total menor que isso
model = Word2Vec(livro, min_count = 1)
vocabulary = model.wv.vocab
print(vocabulary)
# Out:
# {'cont': <gensim.models.keyedvectors.Vocab object at 0x7f96bda9bc18>, 'flumin': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83438>, 'obr': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83518>, 'complet': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83550>, 'mach': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83588>, 'assil': <gensim.models.keyedvectors.Vocab object at 0x7f96bda835c0>, 'vol': <gensim.models.keyedvectors.Vocab object at 0x7f96bda835f8>, 'ii': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83630>, 'rio': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83668>, 'jan': <gensim.models.keyedvectors.Vocab object at 0x7f96bda836a0>, 'nov': <gensim.models.keyedvectors.Vocab object at 0x7f96bda836d8>, 'aguil': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83710>, 'public': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83748>, 'orig': <gensim.models.keyedvectors.Vocab object at 0x7f96bda83780>, 'edit': <gensim.models.keyedv
# ...

# %%
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8766007423400879), ('pobr', 0.8226537704467773), ('cássi', 0.7839900851249695), ('chor', 0.7749547958374023), ('zombel', 0.7652566432952881), ('jaqu', 0.7605704665184021), ('mulh', 0.7562842965126038), ('infeliz', 0.7560986280441284), ('mam', 0.7419736385345459), ('compassiv', 0.7402266263961792)]

# %%
model = Word2Vec(livro, min_count = 2)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8901476860046387), ('pobr', 0.8097499012947083), ('brinc', 0.7458780407905579), ('mulh', 0.7303947806358337), ('prantei', 0.7176837921142578), ('infeliz', 0.7175880670547485), ('gord', 0.716343879699707), ('maud', 0.7122678756713867), ('lind', 0.7114315032958984), ('afecç', 0.705905556678772)]

# %%
model = Word2Vec(livro, min_count = 3)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.9021799564361572), ('pobr', 0.8078157901763916), ('chor', 0.752124547958374), ('afecç', 0.7450765371322632), ('infeliz', 0.733055591583252), ('mulh', 0.7256702184677124), ('ai', 0.7027130126953125), ('suspir', 0.7010587453842163), ('araken', 0.7004947066307068), ('esp', 0.6962175369262695)]

# %%
# adicionando o segundo parâmetro
# window - max distancia entre a palavra
model = Word2Vec(livro, window = 1)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8730306029319763), ('raparig', 0.8080211877822876), ('rapaz', 0.8068504333496094), ('cabocl', 0.7996717691421509), ('sar', 0.7982788681983948), ('flor', 0.7904707193374634), ('mulh', 0.7860748767852783), ('moç', 0.7814487218856812), ('lucind', 0.7813763618469238), ('valéri', 0.7770613431930542)]

# %%
# adicionando o segundo parâmetro
# window - max distancia entre a palavra
model = Word2Vec(livro, window = 2)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8782747387886047), ('raparig', 0.8031372427940369), ('sar', 0.7950926423072815), ('mulh', 0.7896744012832642), ('infeliz', 0.7737412452697754), ('moç', 0.7557517886161804), ('ai', 0.7546550035476685), ('encant', 0.74688720703125), ('chor', 0.7364404201507568), ('gord', 0.7349068522453308)]

# %%
# adicionando o segundo parâmetro
# window - max distancia entre a palavra
model = Word2Vec(livro, window = 3)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8660604953765869), ('mulh', 0.7573572993278503), ('sar', 0.7531975507736206), ('pobr', 0.7408826351165771), ('infeliz', 0.7376229763031006), ('raparig', 0.7303605079650879), ('chor', 0.7294318675994873), ('gord', 0.7203282713890076), ('ai', 0.718721866607666), ('moç', 0.7049205303192139)]

# %%
# adicionando o terceiro parâmetro
#size -  dimensão dos vetores (50, 300)
model = Word2Vec(livro, size = 50)
#model = Word2Vec(livro, size = 300)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8519887328147888), ('pobr', 0.8031423091888428), ('chor', 0.7335568070411682), ('defunt', 0.7245583534240723), ('rechonchud', 0.7233836054801941), ('infeliz', 0.7165205478668213), ('mulh', 0.7059650421142578), ('debulh', 0.6807690858840942), ('ai', 0.6776978969573975), ('gentil', 0.6772313117980957)]

# %%
# adicionando o terceiro parâmetro
#size -  dimensão dos vetores (50, 300)
model = Word2Vec(livro, size = 100)
#model = Word2Vec(livro, size = 300)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8836269378662109), ('pobr', 0.7843778133392334), ('chor', 0.742942214012146), ('mulh', 0.7275882959365845), ('rechonchud', 0.7195644974708557), ('sar', 0.712054967880249), ('ai', 0.6905398368835449), ('déruchett', 0.6893371939659119), ('moç', 0.6888837218284607), ('infeliz', 0.6854896545410156)]

# %%
# adicionando o terceiro parâmetro
#size -  dimensão dos vetores (50, 300)
model = Word2Vec(livro, size = 300)
#model = Word2Vec(livro, size = 300)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8551060557365417), ('pobr', 0.8169516324996948), ('mulh', 0.7581074833869934), ('chor', 0.7462801933288574), ('infeliz', 0.7417702078819275), ('defunt', 0.7394551634788513), ('lind', 0.7390841841697693), ('gentil', 0.7378020286560059), ('rechonchud', 0.7347753643989563), ('idos', 0.7110131978988647)]

# %%
# adicionando o quarto parâmetro
# sample - O limite para configurar quais palavras de alta frequência são reduzidas aleatoriamente.  (0, 1e-5)
model = Word2Vec(livro, sample=0)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8578616380691528), ('pobr', 0.7665186524391174), ('mulh', 0.7410837411880493), ('adult', 0.6729074120521545), ('moç', 0.6675149202346802), ('idos', 0.6601959466934204), ('angél', 0.6559177041053772), ('moc', 0.6424685120582581), ('brinc', 0.6412651538848877), ('defunt', 0.6345162391662598)]

# %%
# adicionando o quarto parâmetro
# sample - O limite para configurar quais palavras de alta frequência são reduzidas aleatoriamente.  (0, 1e-5)
model = Word2Vec(livro, sample=0.0001)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.9984862804412842), ('fiq', 0.9977604150772095), ('silenci', 0.9973811507225037), ('desped', 0.9972484111785889), ('impaci', 0.9971294403076172), ('quiet', 0.9970319271087646), ('magr', 0.9968275427818298), ('depress', 0.9966525435447693), ('brinc', 0.9966315627098083), ('cov', 0.9965716004371643)]

# %%
# adicionando o quarto parâmetro
# sample - O limite para configurar quais palavras de alta frequência são reduzidas aleatoriamente.  (0, 1e-5)
model = Word2Vec(livro, sample=1e-5)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('et', 0.9998571872711182), ('le', 0.9998369812965393), ('flam', 0.9998328685760498), ('poem', 0.9998319149017334), ('qui', 0.9998281598091125), ('serp', 0.9998277425765991), ('en', 0.9998261332511902), ('pieuvr', 0.9998252987861633), ('il', 0.9998225569725037), ('mon', 0.9998224973678589)]

# %%
# adicionando o quinto parâmetro
# alpha = The initial learning rate - (0.01, 0.05)
model = Word2Vec(livro, alpha=0.01)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('perplex', 0.9942436218261719), ('menin', 0.99371737241745), ('cans', 0.993349552154541), ('envelhec', 0.9933419227600098), ('amarg', 0.9927641153335571), ('henriquet', 0.9927566647529602), ('afinal', 0.992545485496521), ('lembranç', 0.9925143122673035), ('maltrat', 0.9924908876419067), ('mam', 0.9923932552337646)]

# %%
# adicionando o quinto parâmetro
# alpha = The initial learning rate - (0.01, 0.05)
model = Word2Vec(livro, alpha=0.03)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8721671104431152), ('pobr', 0.7860276699066162), ('chor', 0.7039370536804199), ('gentil', 0.6772598028182983), ('brinc', 0.6734775900840759), ('defunt', 0.6450901627540588), ('moc', 0.644620418548584), ('moç', 0.6444464921951294), ('mulh', 0.6437029838562012), ('travess', 0.6380662322044373)]

# %%
# adicionando o quinto parâmetro
# alpha = The initial learning rate - (0.01, 0.05)
model = Word2Vec(livro, alpha=0.05)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.756698489189148), ('travess', 0.5594918727874756), ('moç', 0.5594148635864258), ('moc', 0.5471585392951965), ('pobr', 0.5329721570014954), ('chor', 0.5318840146064758), ('brinc', 0.5258294343948364), ('mam', 0.49618613719940186), ('ai', 0.4933629631996155), ('bonec', 0.4932902753353119)]

# %%
# adicionando o sexto parâmetro
# min_alpha = A taxa de aprendizado cai linearmente para min_alpha à medida que o treinamento avança. To set it: alpha - (min_alpha * epochs) ~ 0.00
model = Word2Vec(livro, min_alpha=0.0001)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8792848587036133), ('pobr', 0.8235660791397095), ('chor', 0.7429424524307251), ('rechonchud', 0.7336429357528687), ('mulh', 0.7330321073532104), ('infeliz', 0.7236139178276062), ('debulh', 0.7072736620903015), ('defunt', 0.7037495374679565), ('moç', 0.6939369440078735), ('gentil', 0.6917238235473633)]

# %%
# adicionando o sexto parâmetro
# min_alpha = A taxa de aprendizado cai linearmente para min_alpha à medida que o treinamento avança. To set it: alpha - (min_alpha * epochs) ~ 0.00
model = Word2Vec(livro, min_alpha=0.0007)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8774821758270264), ('pobr', 0.8158308267593384), ('chor', 0.725193977355957), ('ai', 0.7154080271720886), ('defunt', 0.7101061940193176), ('debulh', 0.7066912651062012), ('sar', 0.704251766204834), ('gord', 0.6982306241989136), ('infeliz', 0.6872920393943787), ('moc', 0.6799101233482361)]

# %%
# adicionando o sexto parâmetro
# min_alpha = A taxa de aprendizado cai linearmente para min_alpha à medida que o treinamento avança. To set it: alpha - (min_alpha * epochs) ~ 0.00
model = Word2Vec(livro, min_alpha=0.001)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8749912977218628), ('pobr', 0.7900400161743164), ('chor', 0.7357219457626343), ('mulh', 0.7239874601364136), ('rechonchud', 0.720515251159668), ('travess', 0.6940726041793823), ('sar', 0.6926114559173584), ('ai', 0.6878499388694763), ('moç', 0.6834261417388916), ('déruchett', 0.6814075112342834)]

# %%
# adicionando o sétimo parâmetro
# negative = If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
model = Word2Vec(livro, negative=5)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.882605791091919), ('pobr', 0.7981277704238892), ('chor', 0.7508299350738525), ('rechonchud', 0.7291150093078613), ('mulh', 0.7279195785522461), ('sar', 0.7006439566612244), ('infeliz', 0.6981703042984009), ('moç', 0.6932590007781982), ('ai', 0.6920814514160156), ('déruchett', 0.6887561082839966)]

# %%
# adicionando o sétimo parâmetro
# negative = If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
model = Word2Vec(livro, negative=10)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8596467971801758), ('pobr', 0.754128098487854), ('chor', 0.7099028825759888), ('mulh', 0.6984434127807617), ('infeliz', 0.6897510290145874), ('travess', 0.6708565950393677), ('ai', 0.6708379983901978), ('gentil', 0.6590846180915833), ('moç', 0.6567850112915039), ('lind', 0.6507751941680908)]

# %%
# adicionando o sétimo parâmetro
# negative = If > 0, negative sampling will be used, the int for negative specifies how many "noise words" should be drown. If set to 0, no negative sampling is used. - (5, 20)
model = Word2Vec(livro, negative=20)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8675627708435059), ('pobr', 0.7720332145690918), ('chor', 0.6850702166557312), ('mulh', 0.6719133853912354), ('ai', 0.6590455770492554), ('infeliz', 0.6531451940536499), ('moç', 0.6482760310173035), ('raparig', 0.6272867918014526), ('gentil', 0.6254560947418213), ('donzel', 0.6236769556999207)]

# %%
# adicionando o oitavo parâmetro
# workers = Use esses muitos threads de trabalho para treinar o modelo (= treinamento mais rápido com máquinas multicore)
model = Word2Vec(livro, workers=1)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8673205375671387), ('pobr', 0.81424880027771), ('mulh', 0.7396925687789917), ('brinc', 0.7380346059799194), ('chor', 0.732322633266449), ('rechonchud', 0.7262236475944519), ('moç', 0.7082854509353638), ('travess', 0.7030996680259705), ('magr', 0.6790069937705994), ('lind', 0.6761764287948608)]

# %%
# adicionando o oitavo parâmetro
# workers = Use esses muitos threads de trabalho para treinar o modelo (= treinamento mais rápido com máquinas multicore)
model = Word2Vec(livro, workers=2)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8699434399604797), ('pobr', 0.8147013187408447), ('brinc', 0.7399952411651611), ('mulh', 0.7376605868339539), ('rechonchud', 0.7309184074401855), ('chor', 0.7259337902069092), ('moç', 0.7064615488052368), ('travess', 0.7003229856491089), ('gord', 0.6814228296279907), ('magr', 0.6808831691741943)]

# %%
# adicionando o oitavo parâmetro
# workers = Use esses muitos threads de trabalho para treinar o modelo (= treinamento mais rápido com máquinas multicore)
model = Word2Vec(livro, workers=3)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8904693126678467), ('pobr', 0.7992077469825745), ('chor', 0.7547658085823059), ('debulh', 0.7104724645614624), ('mulh', 0.7090842723846436), ('déruchett', 0.7058857679367065), ('ai', 0.7010831832885742), ('sar', 0.6963983774185181), ('rechonchud', 0.6912151575088501), ('gentil', 0.685713529586792)]

# %%
# sg ({0, 1}, optional) – Training algorithm: 1 for skip-gram; otherwise CBOW.
model = Word2Vec(livro, sg = 1)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.8088682889938354), ('mam', 0.7719722390174866), ('moc', 0.7364770770072937), ('idos', 0.7316840291023254), ('pequenin', 0.7226258516311646), ('enlouquec', 0.7222689390182495), ('travess', 0.7221168279647827), ('raparig', 0.712837815284729), ('cox', 0.7090458273887634), ('hélv', 0.7034623622894287)]

# %%
# sg ({0, 1}, optional) – Training algorithm: 1 for skip-gram; otherwise CBOW.
model = Word2Vec(livro, sg = 0)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.865668773651123), ('pobr', 0.8110633492469788), ('chor', 0.7595417499542236), ('infeliz', 0.708456814289093), ('mulh', 0.7024180293083191), ('adult', 0.6934205293655396), ('ai', 0.6923128962516785), ('brinc', 0.68892902135849), ('lép', 0.6847098469734192), ('gentil', 0.6822653412818909)]

# %%
model = Word2Vec(livro, min_count = 2, window = 2, size = 100, sample=0, alpha=0.05,  min_alpha=0.0007, negative=5, workers=2)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.6471962928771973), ('mulh', 0.5550150871276855), ('raparig', 0.5485472679138184), ('jaqu', 0.5268124938011169), ('mam', 0.5136051177978516), ('moç', 0.5094566345214844), ('maud', 0.5035845637321472), ('crianc', 0.4999349117279053), ('agreg', 0.4951401352882385), ('fl', 0.486992210149765)]

# %%
model = Word2Vec(livro, min_count = 2, window = 2, size = 50, sample=0, alpha=0.05,  min_alpha=0.0007, negative=5, workers=2)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.7246878743171692), ('mulh', 0.687826931476593), ('raparig', 0.6512618660926819), ('moç', 0.6473290324211121), ('rapaz', 0.6397895216941833), ('jaqu', 0.5658646821975708), ('crianc', 0.5593134164810181), ('moc', 0.5480727553367615), ('mam', 0.5433167219161987), ('inác', 0.5422483086585999)]

# %%
model = Word2Vec(livro, min_count = 2, window = 2, size = 50, sample=0, alpha=0.05,  min_alpha=0.0007, negative=5, workers=2, sg=1)
vocabulary = model.wv.vocab
#print(vocabulary)
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.7732235193252563), ('mulh', 0.7654624581336975), ('mam', 0.7291663289070129), ('hom', 0.7228530049324036), ('moç', 0.7127710580825806), ('desventur', 0.7126730680465698), ('dement', 0.7111368179321289), ('jaqu', 0.7109994292259216), ('cappon', 0.7057555913925171), ('severin', 0.6948126554489136)]

# %%
model.train(livro, total_examples=model.corpus_count, epochs=model.iter)
# Out:
# /home/caroline/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (6550895, 6581960)

# %%
similar_words = model.wv.most_similar("crianç")
print(similar_words)
# Out:
# [('menin', 0.7851216793060303), ('mulh', 0.7637354135513306), ('jaqu', 0.7296269536018372), ('dement', 0.69852614402771), ('moç', 0.6921339631080627), ('hom', 0.6869657039642334), ('desventur', 0.6866254806518555), ('mam', 0.6746957898139954), ('criançol', 0.6739794611930847), ('sinfrôni', 0.6738657355308533)]

# %%
# import gensim
# model = Word2Vec(livro, min_count = 2, window = 2, size = 50, sample=0, alpha=0.05,  min_alpha=0.0007, negative=5, workers=2)
# word = 'crianç'
# input_word_indices = [] #indice no vocabulário das palavras do contexto 
# l1 =  #vetor de representação da palavra
# alpha = 0.05 # taxa de aprendizado
# gensim.models.word2vec.train_cbow_pair(model, word, input_word_indices, l1, alpha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d466ab4266ac> in <module>
#       1 import gensim
# ----> 2 gensim.models.word2vec.train_cbow_pair(model, word, input_word_indices, l1, alpha, learn_vectors=True, learn_hidden=True, compute_loss=False, context_vectors=None, context_locks=None, is_ft=False)
#
# NameError: name 'input_word_indices' is not defined

# %%
# gensim.models.word2vec.train_sg_pair(model, word, context_index, alpha, learn_vectors=True, learn_hidden=True, context_vectors=None, context_locks=None, compute_loss=False, is_ft=False)
